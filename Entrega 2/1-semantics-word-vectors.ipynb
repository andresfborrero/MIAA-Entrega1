# %% [markdown]
# # Semantica y Vectores de palabra con Spacy
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ohtar10/icesi-nlp/blob/main/Sesion2/1-semantics-word-vectors.ipynb)
#
# En este notebook exploraremos el concepto de word vectors utilizando la librería Spacy.
#
# ## Referencias
# * [NLP - Natural Language Processing With Python](https://www.udemy.com/course/nlp-natural-language-processing-with-python)

# %%
import pkg_resources
import warnings

warnings.filterwarnings('ignore')

installed_packages = [package.key for package in pkg_resources.working_set]
IN_COLAB = 'google-colab' in installed_packages

# %%
#!test '{IN_COLAB}' = 'True' && wget  https://github.com/Ohtar10/icesi-nlp/raw/refs/heads/main/requirements.txt && pip install -r requirements.txt

# %%
#!python -m spacy download en_core_web_lg

# %%
#%pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl

import spacy

nlp = spacy.load('en_core_web_lg')
# Out:
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ---------------------------------------- 0.0/587.7 MB ? eta -:--:--
#      ---------------------------------------- 1.0/587.7 MB 6.3 MB/s eta 0:01:34
#       -------------------------------------- 8.4/587.7 MB 23.7 MB/s eta 0:00:25
#       ------------------------------------- 11.3/587.7 MB 20.7 MB/s eta 0:00:28
#      - ------------------------------------ 19.1/587.7 MB 25.2 MB/s eta 0:00:23
#      - ------------------------------------ 25.7/587.7 MB 26.3 MB/s eta 0:00:22
#      -- ----------------------------------- 31.5/587.7 MB 28.9 MB/s eta 0:00:20
#      -- ----------------------------------- 32.5/587.7 MB 23.2 MB/s eta 0:00:24
#      -- ----------------------------------- 40.4/587.7 MB 25.2 MB/s eta 0:00:22
#      --- ---------------------------------- 49.3/587.7 MB 27.1 MB/s eta 0:00:20
#      --- ---------------------------------- 52.7/587.7 MB 26.2 MB/s eta 0:00:21
#      --- ---------------------------------- 56.4/587.7 MB 24.9 MB/s eta 0:00:22
#      ---- --------------------------------- 63.7/587.7 MB 25.9 MB/s eta 0:00:21
#      ---- --------------------------------- 73.4/587.7 MB 27.5 MB/s eta 0:00:19
#      ---- --------------------------------- 73.7/587.7 MB 25.5 MB/s eta 0:00:21
#      ---- --------------------------------- 76.8/587.7 MB 24.7 MB/s eta 0:00:21
#      ----- -------------------------------- 84.4/587.7 MB 25.4 MB/s eta 0:00:20
#      ------ ------------------------------ 101.4/587.7 MB 28.8 MB/s eta 0:00:17
#      ------ ------------------------------ 111.1/587.7 MB 29.8 MB/s eta 0:00:16
#      ------- ----------------------------- 117.2/587.7 MB 29.7 MB/s eta 0:00:16
#      ------- ----------------------------- 125.8/587.7 MB 30.3 MB/s eta 0:00:16
#      -------- ---------------------------- 137.4/587.7 MB 31.5 MB/s eta 0:00:15
#      --------- --------------------------- 144.2/587.7 MB 31.7 MB/s eta 0:00:15
#      --------- --------------------------- 147.1/587.7 MB 30.6 MB/s eta 0:00:15
#      --------- --------------------------- 149.2/587.7 MB 29.9 MB/s eta 0:00:15
#      --------- --------------------------- 157.3/587.7 MB 30.4 MB/s eta 0:00:15
#      ---------- -------------------------- 167.8/587.7 MB 31.1 MB/s eta 0:00:14
#      ---------- -------------------------- 167.8/587.7 MB 31.1 MB/s eta 0:00:14
#      ---------- -------------------------- 168.0/587.7 MB 28.7 MB/s eta 0:00:15
#      ---------- -------------------------- 169.9/587.7 MB 27.9 MB/s eta 0:00:15
#      ----------- ------------------------- 178.3/587.7 MB 28.4 MB/s eta 0:00:15
#      ----------- ------------------------- 188.7/587.7 MB 29.1 MB/s eta 0:00:14
#      ----------- ------------------------- 188.7/587.7 MB 29.1 MB/s eta 0:00:14
#      ----------- ------------------------- 189.3/587.7 MB 27.4 MB/s eta 0:00:15
#      ------------ ------------------------ 194.0/587.7 MB 27.1 MB/s eta 0:00:15
#      ------------ ------------------------ 199.2/587.7 MB 27.4 MB/s eta 0:00:15
#      ------------ ------------------------ 199.5/587.7 MB 27.0 MB/s eta 0:00:15
#      ------------ ------------------------ 200.3/587.7 MB 25.8 MB/s eta 0:00:16
#      ------------ ------------------------ 206.0/587.7 MB 25.7 MB/s eta 0:00:15
#      ------------- ----------------------- 217.1/587.7 MB 26.4 MB/s eta 0:00:15
#      -------------- ---------------------- 227.8/587.7 MB 27.0 MB/s eta 0:00:14
#      -------------- ---------------------- 230.7/587.7 MB 27.2 MB/s eta 0:00:14
#      -------------- ---------------------- 232.0/587.7 MB 26.3 MB/s eta 0:00:14
#      --------------- --------------------- 241.2/587.7 MB 26.6 MB/s eta 0:00:14
#      --------------- --------------------- 244.8/587.7 MB 26.4 MB/s eta 0:00:13
#      --------------- --------------------- 252.7/587.7 MB 26.7 MB/s eta 0:00:13
#      ---------------- -------------------- 262.1/587.7 MB 27.1 MB/s eta 0:00:13
#      ---------------- -------------------- 267.1/587.7 MB 27.2 MB/s eta 0:00:12
#      ----------------- ------------------- 276.6/587.7 MB 27.8 MB/s eta 0:00:12
#      ----------------- ------------------- 283.1/587.7 MB 28.0 MB/s eta 0:00:11
#      ----------------- ------------------- 284.2/587.7 MB 27.2 MB/s eta 0:00:12
#      ------------------ ------------------ 292.6/587.7 MB 27.1 MB/s eta 0:00:11
#      ------------------ ------------------ 293.9/587.7 MB 27.3 MB/s eta 0:00:11
#      ------------------ ------------------ 297.3/587.7 MB 27.2 MB/s eta 0:00:11
#      ------------------- ----------------- 304.1/587.7 MB 27.3 MB/s eta 0:00:11
#      ------------------- ----------------- 305.1/587.7 MB 26.6 MB/s eta 0:00:11
#      ------------------- ----------------- 313.8/587.7 MB 26.4 MB/s eta 0:00:11
#      -------------------- ---------------- 325.1/587.7 MB 27.4 MB/s eta 0:00:10
#      --------------------- --------------- 335.3/587.7 MB 27.5 MB/s eta 0:00:10
#      --------------------- --------------- 335.5/587.7 MB 28.0 MB/s eta 0:00:09
#      --------------------- --------------- 336.1/587.7 MB 27.1 MB/s eta 0:00:10
#      --------------------- --------------- 340.8/587.7 MB 27.1 MB/s eta 0:00:10
#      ---------------------- -------------- 350.0/587.7 MB 27.0 MB/s eta 0:00:09
#      ---------------------- -------------- 360.2/587.7 MB 26.8 MB/s eta 0:00:09
#      ----------------------- ------------- 367.5/587.7 MB 26.5 MB/s eta 0:00:09
#      ----------------------- ------------- 373.3/587.7 MB 26.4 MB/s eta 0:00:09
#      ----------------------- ------------- 377.5/587.7 MB 26.5 MB/s eta 0:00:08
#      ----------------------- ------------- 378.5/587.7 MB 25.8 MB/s eta 0:00:09
#      ------------------------ ------------ 386.9/587.7 MB 25.7 MB/s eta 0:00:08
#      ------------------------ ------------ 396.1/587.7 MB 25.6 MB/s eta 0:00:08
#      ------------------------- ----------- 398.5/587.7 MB 25.7 MB/s eta 0:00:08
#      ------------------------- ----------- 400.6/587.7 MB 24.9 MB/s eta 0:00:08
#      ------------------------- ----------- 408.9/587.7 MB 25.4 MB/s eta 0:00:08
#      ------------------------- ----------- 409.5/587.7 MB 25.0 MB/s eta 0:00:08
#      -------------------------- ---------- 415.0/587.7 MB 24.9 MB/s eta 0:00:07
#      -------------------------- ---------- 422.8/587.7 MB 25.0 MB/s eta 0:00:07
#      -------------------------- ---------- 422.8/587.7 MB 25.0 MB/s eta 0:00:07
#      --------------------------- --------- 429.9/587.7 MB 25.3 MB/s eta 0:00:07
#      --------------------------- --------- 430.4/587.7 MB 25.1 MB/s eta 0:00:07
#      --------------------------- --------- 434.9/587.7 MB 25.1 MB/s eta 0:00:07
#      --------------------------- --------- 441.2/587.7 MB 25.0 MB/s eta 0:00:06
#      ---------------------------- -------- 448.5/587.7 MB 24.7 MB/s eta 0:00:06
#      ----------------------------- ------- 461.4/587.7 MB 26.5 MB/s eta 0:00:05
#      ----------------------------- ------- 462.2/587.7 MB 26.9 MB/s eta 0:00:05
#      ----------------------------- ------- 468.7/587.7 MB 27.0 MB/s eta 0:00:05
#      ----------------------------- ------- 471.9/587.7 MB 27.2 MB/s eta 0:00:05
#      ----------------------------- ------- 475.0/587.7 MB 26.3 MB/s eta 0:00:05
#      ------------------------------ ------ 483.7/587.7 MB 26.1 MB/s eta 0:00:04
#      ------------------------------- ----- 498.6/587.7 MB 27.3 MB/s eta 0:00:04
#      ------------------------------- ----- 503.3/587.7 MB 27.6 MB/s eta 0:00:04
#      ------------------------------- ----- 505.7/587.7 MB 26.8 MB/s eta 0:00:04
#      -------------------------------- ---- 513.8/587.7 MB 27.0 MB/s eta 0:00:03
#      -------------------------------- ---- 522.5/587.7 MB 26.9 MB/s eta 0:00:03
#      --------------------------------- --- 534.8/587.7 MB 27.5 MB/s eta 0:00:02
#      --------------------------------- --- 539.5/587.7 MB 27.1 MB/s eta 0:00:02
#      ---------------------------------- -- 548.7/587.7 MB 27.8 MB/s eta 0:00:02
#      ---------------------------------- -- 555.7/587.7 MB 28.3 MB/s eta 0:00:02
#      ----------------------------------- - 557.1/587.7 MB 27.8 MB/s eta 0:00:02
#      ----------------------------------- - 566.2/587.7 MB 28.4 MB/s eta 0:00:01
#      ------------------------------------  574.9/587.7 MB 28.6 MB/s eta 0:00:01
#      ------------------------------------  577.0/587.7 MB 28.5 MB/s eta 0:00:01
#      ------------------------------------  581.7/587.7 MB 27.8 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 27.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 27.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 27.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 27.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 27.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 27.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 27.6 MB/s eta 0:00:01
#      ------------------------------------- 587.7/587.7 MB 24.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from en-core-web-lg==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.10)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.11.7)
# Requirement already satisfied: jinja2 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\andres.borreroc\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2025.4.26)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.5)
# Requirement already satisfied: colorama in c:\users\andres.borreroc\appdata\roaming\python\python310\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (14.1.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (7.3.0.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\andres.borreroc\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.19.1)
# Requirement already satisfied: wrapt in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.17.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\andres.borreroc\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.7.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# En esta ocasión, este modelo de Spacy más grande ya contiene vectores de palabras densos de 300 dimensiones que podemos utilizar de inmediato.
#
# Por ejemplo, exploremos la palabra `lion`

# %%
nlp(u'lion').vector
# Out:
# array([  1.2746  ,   0.46242 ,  -1.1829  ,  -5.2661  ,  -2.7128  ,
#          1.8521  ,  -0.94273 ,   2.1865  ,   6.503   ,   0.6704  ,
#          1.5361  ,   2.5992  ,  -0.36233 ,   4.3965  ,  -6.5644  ,
#          1.6141  ,  -1.2897  ,   2.1184  ,  -0.63654 ,  -3.4572  ,
#         -4.3771  ,   4.2074  ,  -3.6411  ,  -0.97214 ,   1.3253  ,
#         -2.3125  ,  -3.6531  ,  -2.8398  ,   2.7913  ,  -1.53    ,
#         -2.9984  ,  -2.6357  ,   0.50615 ,  -2.6925  ,   4.3401  ,
#         -5.6017  ,   0.045691,   4.3832  ,  -0.19535 ,  -1.0751  ,
#          0.32172 ,   2.4395  ,   4.6638  ,   3.4471  ,  -3.3847  ,
#         -1.8238  ,   0.70212 ,   0.58557 ,   5.0032  ,  -3.1072  ,
#          1.2364  ,   7.4595  ,   0.057368,   1.0111  ,  -1.0827  ,
#          0.69113 ,   2.8009  ,  -3.4383  ,  -1.0599  ,  -2.2627  ,
#         -5.149   ,  -5.0636  ,   3.1405  ,   1.0793  ,  -0.72892 ,
#         -3.9939  ,  -0.69551 ,  -0.55767 ,   3.2555  ,  -2.9449  ,
#          4.7114  ,   1.6388  ,   1.3828  ,   1.4255  ,  -3.2334  ,
#         -2.274   ,  -1.8136  ,   2.2966  ,   2.5462  ,   1.0722  ,
#         -0.73447 ,   1.2148  ,  -0.9196  ,  -0.065012,   2.088   ,
#          0.57002 ,   3.5746  ,   1.7192  ,  -8.335   ,   0.71079 ,
#          0.91314 ,  -5.0107  ,   1.899   ,  -4.4658  ,   4.7993  ,
#         -0.39899 ,  -2.673   ,  -2.9354  ,   4.304   ,   1.4336  ,
#          3.7121  ,   0.34882 ,   4.6512  ,  -4.5731  ,  -4.5665  ,
#          1.5988  ,  -0.50383 ,   0.95857 ,   0.68728 ,  -0.39976 ,
#         -3.1922  ,   4.4363  ,  -0.69479 ,  -1.9528  ,   4.9376  ,
#          2.7259  ,   2.2485  ,   5.5734  ,   2.5842  ,   4.7836  ,
#         -1.0274  ,   2.2703  ,  -2.0696  ,  -1.0642  ,  -4.932   ,
#         -2.274   ,   4.1409  ,   0.73313 ,   2.1889  ,  -0.098888,
#          1.6472  ,  -2.3985  ,   2.5911  ,   3.6026  ,   1.885   ,
#          5.7822  ,  -1.4481  ,   1.8914  , -10.044   ,  -5.7452  ,
#         -4.3224  ,  -3.854   ,   2.3084  ,  -0.84018 ,  -0.40526 ,
#          4.7741  ,  -2.3271  ,   7.064   ,   0.95753 ,  -2.356   ,
#          0.83953 ,   0.40004 ,   0.33743 ,   0.8376  ,   3.9285  ,
#          0.05955 ,   2.4422  ,   4.3492  ,   3.9861  ,   2.1043  ,
#         -1.0197  ,  -0.61752 ,  -0.42999 ,  -0.1014  ,  -5.9571  ,
#         -0.53818 ,  -1.7797  ,   1.7446  ,   2.3934  ,  -0.50263 ,
#         -1.6222  ,  -0.37372 ,  -6.8938  ,   0.55018 ,  -2.267   ,
#          0.64912 ,   3.1525  ,  -2.2541  ,  -4.0384  ,   3.206   ,
#          0.14962 ,  -2.6662  ,   0.18167 ,   5.0028  ,   2.1521  ,
#          0.92419 ,   5.4163  ,  -2.2408  ,   1.6585  ,  -5.1625  ,
#          5.029   ,   0.1026  ,  -0.44542 ,   2.0557  ,   3.7778  ,
#          3.8679  ,  -2.7135  ,   5.3242  ,  -3.2916  ,   5.6421  ,
#          5.0466  ,   1.6072  ,  -1.3206  ,   4.2044  ,  -0.33793 ,
#         -3.1139  ,   2.8841  ,  -3.1565  ,  -2.9832  ,  -0.23235 ,
#          2.3259  ,   3.5477  ,  -2.1299  ,  -1.8344  ,   2.7271  ,
#          1.5568  ,   5.6865  ,   0.9412  ,  -2.6412  ,  -5.3254  ,
#          1.3494  ,  -0.47159 ,   2.4979  ,  -1.5568  ,  -1.6911  ,
#         -2.1842  ,   6.0319  ,   0.022573,   2.3824  ,  -1.1002  ,
#          0.90216 ,  -1.9113  ,   1.5527  ,   5.7413  ,  -3.1956  ,
#          0.68655 ,  -1.6068  ,   1.7404  ,  -3.2142  ,   6.4783  ,
#          1.7548  ,  -2.9795  ,   0.97631 ,  -0.018354,  -0.6379  ,
#          0.80559 ,   3.1923  ,   3.3335  ,   4.3068  ,  -1.0819  ,
#         -1.3839  ,  -4.7626  ,  -4.6637  ,  -1.2201  ,  -3.2741  ,
#          1.5204  ,   0.78119 ,   8.7339  ,   1.6009  ,  -0.79332 ,
#          5.8416  ,  -1.485   ,   1.5978  ,   2.9746  ,  -0.30759 ,
#         -1.8023  ,  -4.8344  ,   1.2817  ,  -2.5469  ,   2.6517  ,
#          1.4881  ,   2.1952  ,  -0.12652 ,   1.2223  ,   0.44763 ,
#         -3.1445  ,  -2.2051  ,  -4.1785  ,  -3.6539  ,   5.1929  ,
#          0.78457 ,  -1.2312  ,   5.5624  ,  -1.8462  ,   6.1262  ,
#         -1.6653  ,  -2.7557  ,  -0.066465,  -3.6362  ,   5.2005  ,
#         -1.2865  ,   2.8855  ,   6.1219  ,   1.7824  ,   1.4264  ,
#         10.628   ,  -0.36028 ,   1.9268  ,  -7.835   ,   0.57865 ],
#       dtype=float32)

# %%
nlp(u'lion').vector.shape
# Out:
# (300,)

# %% [markdown]
# Como podemos observar, `lion` es representada por un vector de *300* dimensiones. Esto es lo que llamamos un `Word to Vector` o *Word2Vec*.
#
# Sin embargo, esta no es la única característica de los modelos de Spacy. También podemos tener un vector de documento lo que significa que por cada documento vamos a promediar los vectores de cada vector que lo compone.

# %%
nlp(u'The quick brown fox jumped').vector.shape
# Out:
# (300,)

# %% [markdown]
# ## Comprobando la similitud entre tokens
#
# Recordemos que una de las características más importantes de estos vectores es que desbloquean exitosamente la semantica de las palabras con operaciones aritméticas, tarea que antes era muy difícil con las técnicas más clásicas.
#
# Gracias a que ya contamos con vectores pre-computados, podemos medir la similitud de estas palabras. La similitud se mide con el coseno entre los vectores.
#
# El rango del coseno es $[-1,+1]$, donde valores cercanos a cero, indican que los vectores son ortogonales, es decir su ángulo es de 90 grados y se consideran disimilares. Cuando la similitud es positiva cercano a $1$, quiere decir que ambos vecrtores son similares, ya que su angulo es inferior a 90 grados. Finalmente, cuando la similitud es negativa, cercana a $-1$, quiere decir que los vectores son opuestos, su ángulo es mayor a 90 grados. Esto último es diferente a valores ceranos a 0 ya que lo opuesto también lleva consigo una relación semántica.

# %%
tokens = nlp('king queen jester')

# %% [markdown]
# Por ejemplo, podemos establecer una relación semántica entre un león y un gato, amobos son felinos. Además, entre un gato y una mascota, ya que un gato es usualmente una. Ahora verifiquemos esta suposición aritméticamente:

# %%
def print_similarity(tokens):
    for token in tokens:
        sim = {t:token.similarity(t) for t in tokens}
        print(f'Similarities with word {token}:\n{sim}\n')

print_similarity(tokens)
# Out:
# Similarities with word king:
# {king: 1.0, queen: 0.6108841896057129, jester: 0.5094937682151794}
#
# Similarities with word queen:
# {king: 0.6108841896057129, queen: 1.0, jester: 0.35041603446006775}
#
# Similarities with word jester:
# {king: 0.5094937682151794, queen: 0.35041603446006775, jester: 1.0}

# %% [markdown]
# Naturalmente, cada palabra es completamente similar con sigo misma, por eso para lion, vemos que la similitud es 1. Nótese que la palabra león tiene una similitud de 0.5 con la palabra gato, pero al mismo tiempo tiene una baja similitud con la palabra mascota.
#
# Entonces verdaderamente la similitud entre los vectores puede revelar una relación semántica entre ellos. Y lo mejor es que es sistemáticamente computable con aritmética vectorial.
#
# Observemos otros ejemplos:

# %%
tokens = nlp('like love hate')

# %% [markdown]
# Desde nuestro conocimeinto, sabemos que `love` (amor) y `hate` (odio) son antonimos, es decir, palabras con significado opuesto. Pero como ambas tienden a ser utilizadas en el mismo contexto, sus vectores pueden tener algo de similitud. Esto significa que los vectores son buenos para detectar contexto pero no para obtener definiciones u obtener un significado humanamente entendible de las palabras.

# %%
print_similarity(tokens)
# Out:
# Similarities with word like:
# {like: 1.0, love: 0.5212638974189758, hate: 0.5065141320228577}
#
# Similarities with word love:
# {like: 0.5212638974189758, love: 1.0, hate: 0.5708349943161011}
#
# Similarities with word hate:
# {like: 0.5065141320228577, love: 0.5708349943161011, hate: 1.0}

# %% [markdown]
# Ahora, podemos inspeccionar el vocabulario de Spacy:

# %%
nlp.vocab.vectors.shape
# Out:
# (514157, 300)

# %% [markdown]
# Tenemos un total de $514,157$ palabras con $300$ dimensiones cada una.
#
# Si una palabra no está presente en el vocabulario, significa que no va a tener un vector.

# %%
tokens = nlp('dog cat nargle')
for token in tokens:
    print(token.text, token.has_vector, token.vector_norm, token.is_oov)
# Out:
# dog True 75.254234 False
# cat True 63.188496 False
# nargle False 0.0 True

# %% [markdown]
# Esto debemos tenerlo en cuenta sobretodo a la hora de usar modelos pre-entrenados, si sabemos de antemano que nuestro corpus tiene tokens que no están en el vocabulario, pues lo más seguro es que nuestro modelo no sea lo suficientemente bueno.

# %% [markdown]
# ## Calculando un nuevo vector
# Técnicamente, podemos usar algebra lineal para obtener un vector de una nueva palabra. Veamos el ejemplo clásico de los word embeddings, la relación entre rey, hombre, mujer y reina:

# %%
from scipy import spatial

cosine_similarity = lambda v1, v2: 1 - spatial.distance.cosine(v1, v2)

# %%
king = nlp.vocab['king'].vector
man = nlp.vocab['man'].vector
woman = nlp.vocab['woman'].vector

# %% [markdown]
# Ahora podemos realizar operaciones simples como adición y substracción de vectores y ver lo que nos deja.
#
# Si a `king` le restamos `man` y le sumamos `woman`, quizás nuestra intuición nos diga que el resultado debería ser la palabra `reina` verdad?

# %%
# Notice for king we substract the man features and add the women features.
# We expect the resulting vector to be similar to Queen, princess, highness, etc.
nv = king - man + woman

# %%
cosine_similarity(nv, nlp.vocab['queen'].vector)
# Out:
# 0.6178014748458582

# %%
computed_similarities = {word.text:cosine_similarity(nv, word.vector) 
                         for word in nlp.vocab if word.has_vector and word.is_lower and word.is_alpha
                        }

# %%
computed_similarities = sorted(computed_similarities.items(), key=lambda kv: kv[1], reverse=True)

# %%
computed_similarities[:10]
# Out:
# [('king', 0.8489541040036218),
#  ('queen', 0.6178014748458582),
#  ('and', 0.38990046973701253),
#  ('lord', 0.38926191190469983),
#  ('that', 0.3848358043284852),
#  ('jester', 0.37551937617847275),
#  ('tyrant', 0.3478205322350596),
#  ('where', 0.3385923464745617),
#  ('president', 0.3376784032992368),
#  ('democracy', 0.3343139683773124)]

# %% [markdown]
# Observemos la medida se similitud para la palabra `queen`, is significativamente cerca a lo que queríamos!
